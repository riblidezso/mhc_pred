# %% [markdown]
# # Estimating the distribution of the performance
#
# ---
#
# I have run the training, and CV evaluation of 20 random CV splits with the script xgboost_sample_results.py.
#
#
# To be done with more (100-200).
#
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
res=pd.read_csv('sample_results.txt',sep=' ',header=None,names=['seed','pearson_r'])

# %%
sns.distplot(res.pearson_r)

# %%
sns.boxplot(res.pearson_r)

# %%
print 'Pearson r is :', '%.4f' % np.mean(res.pearson_r),
print '+-','%.4f' % np.std(res.pearson_r)
# Out:
# Pearson r is : 0.8298 +- 0.0004
