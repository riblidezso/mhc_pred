# %%
import os
os.environ['THEANO_FLAGS']='device=gpu'

import subprocess
import time

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import numpy as np
import pandas as pd

#my functions
from utils import load_data,my_keras_cv_predict

#go to working directory
work_dir='/mnt/Data1/ribli/mhc/'
os.chdir(work_dir)
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 670 (CNMeM is disabled, CuDNN 4007)
# /mnt/Data1/ribli/tools/anaconda/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %%
x,y=load_data(hla_representation='one-hot',seq_representation='one-hot')
# Out:
# Reading from file...
# Creating representation...
# Using  83751 data points
# Done, It took: 1.96946501732 s

# %%
#create a very simple deepish model
from keras.models import Sequential
from keras.layers import Dense

#create model creator
def get_model(input_dim):
    """Creates Keras model needed."""
    model = Sequential()
    model.add(Dense(512, input_dim=input_dim,activation='relu'))
    model.add(Dense(1,activation='linear'))
    model.compile(loss='mse', optimizer='adam')
    return model

#train
y_pred=my_keras_cv_predict(get_model,x,y,n_folds=5,patience=3,verbose=2)
# Out:
# Train on 60300 samples, validate on 6700 samples
# Epoch 1/100
# 1s - loss: 1.5224 - val_loss: 1.3733
# Epoch 00000: val_loss improved from inf to 1.37327, saving model to best_model
# Epoch 2/100
# 1s - loss: 1.1798 - val_loss: 1.0849
# Epoch 00001: val_loss improved from 1.37327 to 1.08489, saving model to best_model
# Epoch 3/100
# 1s - loss: 0.9166 - val_loss: 0.9229
# Epoch 00002: val_loss improved from 1.08489 to 0.92286, saving model to best_model
# Epoch 4/100
# 1s - loss: 0.7717 - val_loss: 0.9078
# Epoch 00003: val_loss improved from 0.92286 to 0.90778, saving model to best_model
# Epoch 5/100
# 1s - loss: 0.6789 - val_loss: 0.8228
# Epoch 00004: val_loss improved from 0.90778 to 0.82276, saving model to best_model
# Epoch 6/100
# 1s - loss: 0.6127 - val_loss: 0.8089
# Epoch 00005: val_loss improved from 0.82276 to 0.80894, saving model to best_model
# Epoch 7/100
# 1s - loss: 0.5578 - val_loss: 0.8239
# Epoch 00006: val_loss did not improve
# Epoch 8/100
# 1s - loss: 0.5217 - val_loss: 0.8034
# Epoch 00007: val_loss improved from 0.80894 to 0.80343, saving model to best_model
# Epoch 9/100
# 1s - loss: 0.4789 - val_loss: 0.8088
# Epoch 00008: val_loss did not improve
# Epoch 10/100
# 1s - loss: 0.4497 - val_loss: 0.8202
# Epoch 00009: val_loss did not improve
# Epoch 11/100
# 1s - loss: 0.4227 - val_loss: 0.8147
# Epoch 00010: val_loss did not improve
# Epoch 12/100
# 1s - loss: 0.3986 - val_loss: 0.8044
# Epoch 00011: val_loss did not improve
# Epoch 00011: early stopping
# Train on 60300 samples, validate on 6701 samples
# Epoch 1/100
# 1s - loss: 1.5269 - val_loss: 1.3718
# Epoch 00000: val_loss improved from inf to 1.37181, saving model to best_model
# Epoch 2/100
# 1s - loss: 1.1812 - val_loss: 1.0977
# Epoch 00001: val_loss improved from 1.37181 to 1.09767, saving model to best_model
# Epoch 3/100
# 1s - loss: 0.9030 - val_loss: 0.9174
# Epoch 00002: val_loss improved from 1.09767 to 0.91742, saving model to best_model
# Epoch 4/100
# 1s - loss: 0.7534 - val_loss: 0.8675
# Epoch 00003: val_loss improved from 0.91742 to 0.86748, saving model to best_model
# Epoch 5/100
# 1s - loss: 0.6710 - val_loss: 0.8152
# Epoch 00004: val_loss improved from 0.86748 to 0.81523, saving model to best_model
# Epoch 6/100
# 1s - loss: 0.5968 - val_loss: 0.8168
# Epoch 00005: val_loss did not improve
# Epoch 7/100
# 1s - loss: 0.5494 - val_loss: 0.7895
# Epoch 00006: val_loss improved from 0.81523 to 0.78945, saving model to best_model
# Epoch 8/100
# 1s - loss: 0.5005 - val_loss: 0.7858
# Epoch 00007: val_loss improved from 0.78945 to 0.78582, saving model to best_model
# Epoch 9/100
# 1s - loss: 0.4679 - val_loss: 0.8291
# Epoch 00008: val_loss did not improve
# Epoch 10/100
# 1s - loss: 0.4370 - val_loss: 0.7768
# Epoch 00009: val_loss improved from 0.78582 to 0.77684, saving model to best_model
# Epoch 11/100
# 1s - loss: 0.4095 - val_loss: 0.7899
# Epoch 00010: val_loss did not improve
# Epoch 12/100
# 1s - loss: 0.3870 - val_loss: 0.7816
# Epoch 00011: val_loss did not improve
# Epoch 13/100
# 1s - loss: 0.3637 - val_loss: 0.7941
# Epoch 00012: val_loss did not improve
# Epoch 14/100
# 1s - loss: 0.3447 - val_loss: 0.7988
# Epoch 00013: val_loss did not improve
# Epoch 00013: early stopping
# Train on 60300 samples, validate on 6701 samples
# Epoch 1/100
# 1s - loss: 1.5645 - val_loss: 1.3913
# Epoch 00000: val_loss improved from inf to 1.39125, saving model to best_model
# Epoch 2/100
# 1s - loss: 1.2252 - val_loss: 1.1262
# Epoch 00001: val_loss improved from 1.39125 to 1.12619, saving model to best_model
# Epoch 3/100
# 1s - loss: 0.9506 - val_loss: 0.9389
# Epoch 00002: val_loss improved from 1.12619 to 0.93888, saving model to best_model
# Epoch 4/100
# 1s - loss: 0.7889 - val_loss: 0.8997
# Epoch 00003: val_loss improved from 0.93888 to 0.89966, saving model to best_model
# Epoch 5/100
# 1s - loss: 0.6931 - val_loss: 0.8620
# Epoch 00004: val_loss improved from 0.89966 to 0.86198, saving model to best_model
# Epoch 6/100
# 1s - loss: 0.6233 - val_loss: 0.8053
# Epoch 00005: val_loss improved from 0.86198 to 0.80533, saving model to best_model
# Epoch 7/100
# 1s - loss: 0.5679 - val_loss: 0.8019
# Epoch 00006: val_loss improved from 0.80533 to 0.80187, saving model to best_model
# Epoch 8/100
# 1s - loss: 0.5229 - val_loss: 0.8573
# Epoch 00007: val_loss did not improve
# Epoch 9/100
# 1s - loss: 0.4896 - val_loss: 0.7891
# Epoch 00008: val_loss improved from 0.80187 to 0.78906, saving model to best_model
# Epoch 10/100
# 1s - loss: 0.4552 - val_loss: 0.7897
# Epoch 00009: val_loss did not improve
# Epoch 11/100
# 1s - loss: 0.4300 - val_loss: 0.8245
# Epoch 00010: val_loss did not improve
# Epoch 12/100
# 1s - loss: 0.4053 - val_loss: 0.7832
# Epoch 00011: val_loss improved from 0.78906 to 0.78321, saving model to best_model
# Epoch 13/100
# 1s - loss: 0.3812 - val_loss: 0.8071
# Epoch 00012: val_loss did not improve
# Epoch 14/100
# 1s - loss: 0.3691 - val_loss: 0.8071
# Epoch 00013: val_loss did not improve
# Epoch 15/100
# 1s - loss: 0.3421 - val_loss: 0.8483
# Epoch 00014: val_loss did not improve
# Epoch 16/100
# 1s - loss: 0.3288 - val_loss: 0.8489
# Epoch 00015: val_loss did not improve
# Epoch 00015: early stopping
# Train on 60300 samples, validate on 6701 samples
# Epoch 1/100
# 1s - loss: 1.4996 - val_loss: 1.3446
# Epoch 00000: val_loss improved from inf to 1.34460, saving model to best_model
# Epoch 2/100
# 1s - loss: 1.1402 - val_loss: 1.0560
# Epoch 00001: val_loss improved from 1.34460 to 1.05604, saving model to best_model
# Epoch 3/100
# 1s - loss: 0.8847 - val_loss: 0.9513
# Epoch 00002: val_loss improved from 1.05604 to 0.95129, saving model to best_model
# Epoch 4/100
# 1s - loss: 0.7491 - val_loss: 0.9750
# Epoch 00003: val_loss did not improve
# Epoch 5/100
# 1s - loss: 0.6612 - val_loss: 0.8036
# Epoch 00004: val_loss improved from 0.95129 to 0.80361, saving model to best_model
# Epoch 6/100
# 1s - loss: 0.6002 - val_loss: 0.8003
# Epoch 00005: val_loss improved from 0.80361 to 0.80028, saving model to best_model
# Epoch 7/100
# 1s - loss: 0.5443 - val_loss: 0.8493
# Epoch 00006: val_loss did not improve
# Epoch 8/100
# 1s - loss: 0.5080 - val_loss: 0.7673
# Epoch 00007: val_loss improved from 0.80028 to 0.76733, saving model to best_model
# Epoch 9/100
# 1s - loss: 0.4706 - val_loss: 0.7718
# Epoch 00008: val_loss did not improve
# Epoch 10/100
# 1s - loss: 0.4432 - val_loss: 0.7765
# Epoch 00009: val_loss did not improve
# Epoch 11/100
# 1s - loss: 0.4100 - val_loss: 0.8001
# Epoch 00010: val_loss did not improve
# Epoch 12/100
# 1s - loss: 0.3907 - val_loss: 0.7727
# Epoch 00011: val_loss did not improve
# Epoch 00011: early stopping
# Train on 60300 samples, validate on 6701 samples
# Epoch 1/100
# 1s - loss: 1.4974 - val_loss: 1.3044
# Epoch 00000: val_loss improved from inf to 1.30436, saving model to best_model
# Epoch 2/100
# 1s - loss: 1.1456 - val_loss: 1.0460
# Epoch 00001: val_loss improved from 1.30436 to 1.04605, saving model to best_model
# Epoch 3/100
# 1s - loss: 0.8895 - val_loss: 0.9166
# Epoch 00002: val_loss improved from 1.04605 to 0.91659, saving model to best_model
# Epoch 4/100
# 1s - loss: 0.7497 - val_loss: 0.8467
# Epoch 00003: val_loss improved from 0.91659 to 0.84672, saving model to best_model
# Epoch 5/100
# 1s - loss: 0.6602 - val_loss: 0.8693
# Epoch 00004: val_loss did not improve
# Epoch 6/100
# 1s - loss: 0.5945 - val_loss: 0.8801
# Epoch 00005: val_loss did not improve
# Epoch 7/100
# 1s - loss: 0.5447 - val_loss: 0.8379
# Epoch 00006: val_loss improved from 0.84672 to 0.83786, saving model to best_model
# Epoch 8/100
# 1s - loss: 0.5008 - val_loss: 0.8005
# Epoch 00007: val_loss improved from 0.83786 to 0.80055, saving model to best_model
# Epoch 9/100
# 1s - loss: 0.4630 - val_loss: 0.7939
# Epoch 00008: val_loss improved from 0.80055 to 0.79390, saving model to best_model
# Epoch 10/100
# 1s - loss: 0.4321 - val_loss: 0.8438
# Epoch 00009: val_loss did not improve
# Epoch 11/100
# 1s - loss: 0.4114 - val_loss: 0.7995
# Epoch 00010: val_loss did not improve
# Epoch 12/100
# 1s - loss: 0.3821 - val_loss: 0.8013
# Epoch 00011: val_loss did not improve
# Epoch 13/100
# 1s - loss: 0.3638 - val_loss: 0.8704
# Epoch 00012: val_loss did not improve
# Epoch 00012: early stopping

# %%
# check correlation
plt.figure(figsize=(9,9))
plt.plot(y,y_pred,'.',ms=3,alpha=0.5)
plt.plot(y,y,lw=3,alpha=0.7)
plt.xlim(xmin=-0.5)
from scipy.stats import pearsonr
print 'Correlation:',pearsonr(y,y_pred)
# Out:
# Correlation: (0.75047289384261784, 0.0)

# %% [markdown]
# ### Error depending on the length of peptid

# %%
leng=x[:,-1]
plt.figure(figsize=(12,6))
sns.boxplot(leng,y-y_pred)
plt.xlabel('length of sequence')
dump=plt.ylabel('ic50 error')
